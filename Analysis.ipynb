# %%
import sqlite3
import pandas as pd

# %%
dbfile = 'data_ssim_diff.db'
con = sqlite3.connect(dbfile)
df = pd.read_sql_query('SELECT * FROM Movies', con)
df
# Out:
#     id       movie_name frame_timestamp  frame_norm  frame_dif     median  \
# 0    1  soprano_bad.mp4               1          62   1.169811  43.500000
# 1    2  soprano_bad.mp4               2          63   1.016129  43.125000
# 2    3  soprano_bad.mp4               3          61   0.968254  42.916667
# 3    4  soprano_bad.mp4               4          44   0.721311  41.541667
# 4    5  soprano_bad.mp4               5          38   0.863636  42.291667
# 5    6  soprano_bad.mp4               6          58   1.526316  44.250000
# 6    7  soprano_bad.mp4               7          42   0.724138  42.833333
# 7    8  soprano_bad.mp4               8          44   1.047619  41.875000
# 8    9  soprano_bad.mp4               9          32   0.727273  42.458333
# 9   10  soprano_bad.mp4              10          38   1.187500  42.541667
# 10  11  soprano_bad.mp4              11          51   1.342105  41.750000
# 11  12  soprano_bad.mp4              12          25   0.490196  41.416667
# ...
